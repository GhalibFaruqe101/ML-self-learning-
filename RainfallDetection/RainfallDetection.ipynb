# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import seaborn as sn
warnings.filterwarnings("ignore")

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from imblearn.over_sampling import RandomOverSampler
from xgboost import XGBClassifier
from sklearn.svm import SVC

# %% [markdown]
# Read the data

# %%
df=pd.read_csv("Rainfall.csv")
df.head()
# Out:
#    day  pressure   maxtemp  temparature  mintemp  dewpoint  humidity   cloud   \
# 0    1     1025.9     19.9         18.3     16.8      13.1         72      49
# 1    2     1022.0     21.7         18.9     17.2      15.6         81      83
# 2    3     1019.7     20.3         19.3     18.0      18.4         95      91
# 3    4     1018.9     22.3         20.6     19.1      18.8         90      88
# 4    5     1015.9     21.3         20.7     20.2      19.9         95      81
#
#   rainfall  sunshine           winddirection  windspeed
# 0      yes       9.3                    80.0       26.3
# 1      yes       0.6                    50.0       15.3
# 2      yes       0.0                    40.0       14.2
# 3      yes       1.0                    50.0       16.9
# 4      yes       0.0                    40.0       13.7

# %% [markdown]
# size of the data
# [col, row]

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   day                     366 non-null    int64
#  1   pressure                366 non-null    float64
#  2   maxtemp                 366 non-null    float64
#  3   temparature             366 non-null    float64
#  4   mintemp                 366 non-null    float64
#  5   dewpoint                366 non-null    float64
#  6   humidity                366 non-null    int64
#  7   cloud                   366 non-null    int64
#  8   rainfall                366 non-null    object
#  9   sunshine                366 non-null    float64
#  10           winddirection  365 non-null    float64
#  11  windspeed               365 non-null    float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 34.4+ KB

# %%
df.describe().T
# Out:
#                         count         mean        std    min       25%  \
# day                     366.0    15.756831   8.823592    1.0     8.000
# pressure                366.0  1013.742623   6.414776  998.5  1008.500
# maxtemp                 366.0    26.191257   5.978343    7.1    21.200
# temparature             366.0    23.747268   5.632813    4.9    18.825
# mintemp                 366.0    21.894536   5.594153    3.1    17.125
# dewpoint                366.0    19.989071   5.997021   -0.4    16.125
# humidity                366.0    80.177596  10.062470   36.0    75.000
# cloud                   366.0    71.128415  21.798012    0.0    58.000
# sunshine                366.0     4.419399   3.934398    0.0     0.500
#          winddirection  365.0   101.506849  81.723724   10.0    40.000
# windspeed               365.0    21.536986  10.069712    4.4    13.700
#
#                             50%       75%     max
# day                       16.00    23.000    31.0
# ...

# %% [markdown]
# checking whether there is any null value

# %%
df.isnull().sum()
# Out:
# day                       0
# pressure                  0
# maxtemp                   0
# temparature               0
# mintemp                   0
# dewpoint                  0
# humidity                  0
# cloud                     0
# rainfall                  0
# sunshine                  0
#          winddirection    1
# windspeed                 1
# dtype: int64

# %% [markdown]
# fix the string extra spaces

# %%
df.rename(str.strip, axis='columns', inplace=True)
df.columns
# Out:
# Index(['day', 'pressure', 'maxtemp', 'temparature', 'mintemp', 'dewpoint',
#        'humidity', 'cloud', 'rainfall', 'sunshine', 'winddirection',
#        'windspeed'],
#       dtype='object')

# %% [markdown]
# - first loop though the columns and check for null values.
# - checked if the number of null values greater than 0.
# - took the mean value of the whole column and replace with the null values

# %%
for nul in df.columns:
    if df[nul].isnull().sum()>0:
        null_mean=df[nul].mean()
        df[nul]=df[nul].fillna(null_mean)
        
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# obtained mean value of rest of the column on the day of the rainfall and also not the day the rainfall

# %%
df.groupby('rainfall').mean()
# Out:
#                 day     pressure    maxtemp  temparature    mintemp  \
# rainfall
# no        15.623932  1014.576923  27.070940    24.053846  21.957265
# yes       15.819277  1013.350602  25.777912    23.603213  21.865060
#
#            dewpoint   humidity      cloud  sunshine  winddirection  windspeed
# rainfall
# no        18.766667  73.000000  51.256410  7.586325     103.076923  19.275214
# yes       20.563454  83.550201  80.465863  2.931325     100.769104  22.599747

# %% [markdown]
# removed day from column

# %%
feature=list(df.select_dtypes(include=np.number).columns)
feature.remove("day")
print(feature)
# Out:
# ['pressure', 'maxtemp', 'temparature', 'mintemp', 'dewpoint', 'humidity', 'cloud', 'rainfall', 'sunshine', 'winddirection', 'windspeed']

# %% [markdown]
# replacing data type

# %%
df.replace({'yes':1, 'no':0}, inplace=True)

# %% [markdown]
# plotting the column

# %%
plt.subplots(figsize=(15,8))
for i, col in enumerate(feature):
    plt.subplot(3,4, i+1)
    sn.distplot(df[col])
    plt.tight_layout()
    plt.show

# %%
plt.subplots(figsize=(15,8))
for i, col in enumerate(feature):
    plt.subplot(3,4, i+1)
    sn.boxplot(df[col])
    plt.tight_layout()
    plt.show()

# %%
df.replace({'yes':1, 'no':0}, inplace=True)

# %%
plt.subplots(figsize=(10,10))
sn.heatmap(df.corr()>0.8, annot=True, cbar=False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - we will remove max and min temp is irrelevant as we have temperature
# - we will not remove dew point because it is a distince feature

# %%
df.drop(['maxtemp','mintemp'], axis=1, inplace=True)
feature=df.drop(['rainfall'], axis=1, inplace=True)

# %% [markdown]
# targe variable set to rainfall

# %%
target=df.rainfall

# %% [markdown]
# balance the data

# %%
x_train, X_val, y_train, y_val = train_test_split(feature, target, test_size=0.2, stratify=target, random_state=2)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 x_train, X_val, y_train, y_val = train_test_split(feature, target, test_size=0.2, stratify=target, random_state=2)
#
# File c:\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:203, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     200 to_ignore += ["self", "cls"]
#     201 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 203 validate_parameter_constraints(
#     204     parameter_constraints, params, caller_name=func.__qualname__
#     205 )
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
#
# ...
